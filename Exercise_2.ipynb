# %% [markdown]
# # Exercise 2 using skimage

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean

# %% [markdown]
# # Load brick image

# %%
image = data.brick()

# %%
plt.imshow(image, cmap='gray')
plt.show()

# %% [markdown]
# ## Subsample to create alias & plot

# %%
image_rescaled = rescale(image, 0.1, anti_aliasing=False)

# %%
image.shape

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
ax = axes.ravel()

ax[0].imshow(image, cmap='gray')
ax[0].set_title("Original image")

ax[1].imshow(image_rescaled, cmap='gray')
ax[1].set_title("Aliasing")

ax[0].set_xlim(0, 512)
ax[0].set_ylim(512, 0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ![Exercise_2_plot.png](attachment:Exercise_2_plot.png)

# %% [markdown]
# # References:

# %% [markdown]
# https://scikit-image.org/docs/dev/api/skimage.transform.html

# %% [markdown]
# https://scikit-image.org/docs/stable/api/skimage.data.html#skimage.data.brick
